# %%
# Initialize Otter
import otter
grader = otter.Notebook("hw5.ipynb")

# %% [markdown]
# # CPSC 330 - Applied Machine Learning
#
# ## Homework 5: Putting it all together
# ### Associated lectures: All material till lecture 13
#
# **Due date: Monday, October 28th, 2024 at 11:59pm**

# %% [markdown]
# ## Table of contents
# 0. [Submission instructions](#si)
# 1. [Understanding the problem](#1)
# 2. [Data splitting](#2)
# 3. [EDA](#3)
# 4. [Feature engineering](#4)
# 5. [Preprocessing and transformations](#5)
# 6. [Baseline model](#6)
# 7. [Linear models](#7)
# 8. [Different models](#8)
# 9. [Feature selection](#9)
# 10. [Hyperparameter optimization](#10)
# 11. [Interpretation and feature importances](#11)
# 12. [Results on the test set](#12)
# 13. [Summary of the results](#13)
# 14. [Your takeaway from the course](#15)

# %% [markdown]
# <div class="alert alert-info">
#
# ## Submission instructions
# <hr>
# rubric={points:4}
#
# **You may work with a partner on this homework and submit your assignment as a group.** Below are some instructions on working as a group.
# - The maximum group size is 2.
# - Use group work as an opportunity to collaborate and learn new things from each other.
# - Be respectful to each other and make sure you understand all the concepts in the assignment well.
# - It's your responsibility to make sure that the assignment is submitted by one of the group members before the deadline.
# - You can find the instructions on how to do group submission on Gradescope [here](https://help.gradescope.com/article/m5qz2xsnjy-student-add-group-members).
# - If you would like to use late tokens for the homework, all group members must have the necessary late tokens available. Please note that the late tokens will be counted for all members of the group.
#
#
# Follow the [homework submission instructions](https://github.com/UBC-CS/cpsc330-2024W1/blob/master/docs/homework_instructions.md).
#
# 1. Before submitting the assignment, run all cells in your notebook to make sure there are no errors by doing `Kernel -> Restart Kernel and Clear All Outputs` and then `Run -> Run All Cells`.
# 2. Notebooks with cell execution numbers out of order or not starting from "1" will have marks deducted. Notebooks without the output displayed may not be graded at all (because we need to see the output in order to grade your work).
# 3. Follow the [CPSC 330 homework instructions](https://ubc-cs.github.io/cpsc330-2024W1/docs/homework_instructions.html), which include information on how to do your assignment and how to submit your assignment.
# 4. Upload your solution on Gradescope. Check out this [Gradescope Student Guide](https://lthub.ubc.ca/guides/gradescope-student-guide/) if you need help with Gradescope submission.
# 5. Make sure that the plots and output are rendered properly in your submitted file. If the .ipynb file is too big and doesn't render on Gradescope, also upload a pdf or html in addition to the .ipynb so that the TAs can view your submission on Gradescope.
#
#
# _Note: The assignments will get gradually more open-ended as we progress through the course. In many cases, there won't be a single correct solution. Sometimes you will have to make your own choices and your own decisions (for example, on what parameter values to use when they are not explicitly provided in the instructions). Use your own judgment in such cases and justify your choices, if necessary._
#
# </div>

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ## Imports

# %% [markdown]
# <div class="alert alert-warning">
#
# Imports
#
# </div>
#
# _Points:_ 0

# %%
import pandas as pd

from sklearn.model_selection import train_test_split, cross_val_score, cross_validate
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder, OrdinalEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.dummy import DummyClassifier

from sklearn.feature_selection import RFECV
from sklearn.model_selection import cross_val_predict, GridSearchCV, RandomizedSearchCV
from sklearn.metrics import classification_report, accuracy_score, f1_score, confusion_matrix

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import shap
from scipy.stats import randint

# %% [markdown]
# <!-- END QUESTION -->
#
# ## Introduction <a name="in"></a>
#
# In this homework you will be working on an open-ended mini-project, where you will put all the different things you have learned so far together to solve an interesting problem.
#
# A few notes and tips when you work on this mini-project:
#
# #### Tips
# 1. This mini-project is open-ended, and while working on it, there might be some situations where you'll have to use your own judgment and make your own decisions (as you would be doing when you work as a data scientist). Make sure you explain your decisions whenever necessary.
# 2. **Do not include everything you ever tried in your submission** -- it's fine just to have your final code. That said, your code should be reproducible and well-documented. For example, if you chose your hyperparameters based on some hyperparameter optimization experiment, you should leave in the code for that experiment so that someone else could re-run it and obtain the same hyperparameters, rather than mysteriously just setting the hyperparameters to some (carefully chosen) values in your code.
# 3. If you realize that you are repeating a lot of code try to organize it in functions. Clear presentation of your code, experiments, and results is the key to be successful in this lab. You may use code from lecture notes or previous lab solutions with appropriate attributions.
#
# #### Assessment
# We plan to grade fairly and leniently. We don't have some secret target score that you need to achieve to get a good grade. **You'll be assessed on demonstration of mastery of course topics, clear presentation, and the quality of your analysis and results.** For example, if you just have a bunch of code and no text or figures, that's not good. If you do a bunch of sane things and get a lower accuracy than your friend, don't sweat it.
#
#
# #### A final note
# Finally, this style of this "project" question is different from other assignments. It'll be up to you to decide when you're "done" -- in fact, this is one of the hardest parts of real projects. But please don't spend WAY too much time on this... perhaps "a few hours" (15-20 hours???) is a good guideline for this project . Of course if you're having fun you're welcome to spend as much time as you want! But, if so, try not to do it out of perfectionism or getting the best possible grade. Do it because you're learning and enjoying it. Students from the past cohorts have found such kind of labs useful and fun and I hope you enjoy it as well.

# %% [markdown]
# <br><br>

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ## 1. Pick your problem and explain the prediction problem <a name="1"></a>
# <hr>
# rubric={points:3}
#
# In this mini project, you have the option to choose on which dataset you will be working on. The tasks you will need to carry on will be similar, independently of your choice.
#
# ### Option 1
# You can choose to work on a classification problem of predicting whether a credit card client will default or not.
# For this problem, you will use [Default of Credit Card Clients Dataset](https://www.kaggle.com/uciml/default-of-credit-card-clients-dataset). In this data set, there are 30,000 examples and 24 features, and the goal is to estimate whether a person will default (fail to pay) their credit card bills; this column is labeled "default.payment.next.month" in the data. The rest of the columns can be used as features. You may take some ideas and compare your results with [the associated research paper](https://www.sciencedirect.com/science/article/pii/S0957417407006719), which is available through [the UBC library](https://www.library.ubc.ca/).
#
#
# ### Option 2
# You can choose to work on a regression problem using a [dataset](https://www.kaggle.com/dgomonov/new-york-city-airbnb-open-data) of New York City Airbnb listings from 2019. As usual, you'll need to start by downloading the dataset, then you will try to predict `reviews_per_month`, as a proxy for the popularity of the listing. Airbnb could use this sort of model to predict how popular future listings might be before they are posted, perhaps to help guide hosts create more appealing listings. In reality they might instead use something like vacancy rate or average rating as their target, but we do not have that available here.
#
# > Note there is an updated version of this dataset with more features available [here](http://insideairbnb.com/). The features were are using in `listings.csv.gz` for the New York city datasets. You will also see some other files like `reviews.csv.gz`. For your own interest you may want to explore the expanded dataset and try your analysis there. However, please submit your results on the dataset obtained from Kaggle.
#
#
# **Your tasks:**
#
# 1. Spend some time understanding the options and pick the one you find more interesting (it may help spending some time looking at the documentation available on Kaggle for each dataset).
# 2. After making your choice, focus on understanding the problem and what each feature means, again using the documentation on the dataset page on Kaggle. Write a few sentences on your initial thoughts on the problem and the dataset.
# 3. Download the dataset and read it as a pandas dataframe.

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_1
#
# </div>
#
# _Points:_ 3

# %% [markdown]
# I chose Option 1 - the Default of Credit Card Clients Dataset for this analysis project. After reviewing the dataset documentation, I find this to be an interesting and practical machine learning problem for several reasons:
#
# - This seems to be a binary classification task predicting whether a credit card client will default on payments in the next month
# - These kind of predictions have real business value for financial institutions in risk assessment and decision making
#
# The dataset seems to:
#
# - Contain 30,000 examples with 24 features
# - Features that include a mix of demographic information (gender, education, age, marital status), financial data (credit limit, bill amounts), and historical payment behaviour (payment status and amounts for past 6 months)
#
# Additionally, it seems that the target variable is "default.payment.next.month" (1 = will default, 0 = won't default).

# %%
credit_card_df = pd.read_csv("./data/UCI_Credit_Card.csv", index_col=0)
credit_card_df.head()
# Out:
#     LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# ID
# 1     20000.0    2          2         1   24      2      2     -1     -1
# 2    120000.0    2          2         2   26     -1      2      0      0
# 3     90000.0    2          2         2   34      0      0      0      0
# 4     50000.0    2          2         1   37      0      0      0      0
# 5     50000.0    1          2         1   57     -1      0     -1      0
#
#     PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# ID         ...
# 1      -2  ...        0.0        0.0        0.0       0.0     689.0       0.0
# 2       0  ...     3272.0     3455.0     3261.0       0.0    1000.0    1000.0
# 3       0  ...    14331.0    14948.0    15549.0    1518.0    1500.0    1000.0
# 4       0  ...    28314.0    28959.0    29547.0    2000.0    2019.0    1200.0
# 5       0  ...    20940.0    19146.0    19131.0    2000.0   36681.0   10000.0
#
# ...

# %% [markdown]
# <!-- END QUESTION -->
#
# <br><br>

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ## 2. Data splitting <a name="2"></a>
# <hr>
# rubric={points:2}
#
# **Your tasks:**
#
# 1. Split the data into train (70%) and test (30%) portions with `random_state=123`.
#
# > If your computer cannot handle training on 70% training data, make the test split bigger.

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_2
#
# </div>
#
# _Points:_ 2

# %%
train_df, test_df = train_test_split(credit_card_df, train_size=0.7, random_state=123)

X_train = train_df.drop(columns="default.payment.next.month")
y_train = train_df["default.payment.next.month"]

X_test = test_df.drop(columns="default.payment.next.month")
y_test = test_df["default.payment.next.month"]

display(train_df)
display(test_df)
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# ID
# 16396   320000.0    2          1         2   36      0      0      0      0
# 21449   440000.0    2          1         2   30     -1     -1     -1      0
# 20035   160000.0    2          3         1   44     -2     -2     -2     -2
# 25756   120000.0    2          2         1   30      0      0      0      0
# 1439     50000.0    1          2         2   54      1      2      0      0
# ...          ...  ...        ...       ...  ...    ...    ...    ...    ...
# 28637   380000.0    2          2         1   37      0      0      0      0
# 17731   360000.0    2          1         1   54      1     -2     -2     -1
# 28031    50000.0    2          3         1   29      0      0      0      0
# 15726    30000.0    2          2         2   21      0      0      0      0
# 19967   370000.0    2          1         1   36     -2     -2     -2     -2
#
# ...

# %% [markdown]
# <!-- END QUESTION -->
#
# <br><br>

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ## 3. EDA <a name="3"></a>
# <hr>
# rubric={points:10}
#
# **Your tasks:**
#
# 1. Perform exploratory data analysis on the train set.
# 2. Include at least two summary statistics and two visualizations that you find useful, and accompany each one with a sentence explaining it.
# 3. Summarize your initial observations about the data.
# 4. Pick appropriate metric/metrics for assessment.

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_3
#
# </div>
#
# _Points:_ 10

# %% [markdown]
# #### `train_df.info()`
#
# Observe that are features of the dataset contain non-null, numeric examples.

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21000 entries, 16396 to 19967
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   LIMIT_BAL                   21000 non-null  float64
#  1   SEX                         21000 non-null  int64
#  2   EDUCATION                   21000 non-null  int64
#  3   MARRIAGE                    21000 non-null  int64
#  4   AGE                         21000 non-null  int64
#  5   PAY_0                       21000 non-null  int64
#  6   PAY_2                       21000 non-null  int64
#  7   PAY_3                       21000 non-null  int64
#  8   PAY_4                       21000 non-null  int64
#  9   PAY_5                       21000 non-null  int64
#  10  PAY_6                       21000 non-null  int64
#  11  BILL_AMT1                   21000 non-null  float64
#  12  BILL_AMT2                   21000 non-null  float64
# ...

# %% [markdown]
# #### `train_df.describe()`
#
# Each numeric feature has different ranges. The dataframe below gives us insight on possible transformations needed for specific columns (ex. `SEX` requires one-hot encoding, `AGE` requires scaling, etc.)

# %%
train_df.describe()
# Out:
#             LIMIT_BAL           SEX     EDUCATION      MARRIAGE           AGE  \
# count    21000.000000  21000.000000  21000.000000  21000.000000  21000.000000
# mean    167880.651429      1.600762      1.852143      1.554000     35.500810
# std     130202.682167      0.489753      0.792961      0.521675      9.212644
# min      10000.000000      1.000000      0.000000      0.000000     21.000000
# 25%      50000.000000      1.000000      1.000000      1.000000     28.000000
# 50%     140000.000000      2.000000      2.000000      2.000000     34.000000
# 75%     240000.000000      2.000000      2.000000      2.000000     41.000000
# max    1000000.000000      2.000000      6.000000      3.000000     79.000000
#
#               PAY_0         PAY_2         PAY_3         PAY_4         PAY_5  \
# count  21000.000000  21000.000000  21000.000000  21000.000000  21000.000000
# mean      -0.015429     -0.137095     -0.171619     -0.225238     -0.264429
# ...

# %% [markdown]
# #### Correlation Map
#
# From the correlation map below, observe that the features `PAY_*` are the most correlated to the target variable (`default.payment.next.month`).
#
# > I've decided to use the `seaborn` library in order to create this correlation map. A link to the documentation can be found [here](https://seaborn.pydata.org/)

# %%
corr_map = train_df.corr()
plt.figure(figsize = (25, 25))
sns.heatmap(corr_map, annot = True, cmap = plt.cm.Blues)
plt.title('Correlation map of Features')
plt.show()

# %% [markdown]
# #### Observing Class Imbalance
#
# Observe the percentage and counts of examples and their corresponding values for `default.payment.next.month`. We can confirm that we have class imbalance here.

# %%
train_df['default.payment.next.month'].value_counts(normalize = True)
# Out:
# default.payment.next.month
# 0    0.776762
# 1    0.223238
# Name: proportion, dtype: float64

# %%
plt.hist(train_df['default.payment.next.month'], bins = 10)
plt.xlabel('default.payment.next.month')
plt.ylabel('Count')
plt.title('Target Class Distribution in Dataset')
plt.show()

# %% [markdown]
# #### Summary of Initial Observations
#
# In conclusion, we can see that all features are numerical and there are no missing values. Each feature has a different scale. Some features are ordinal (ex. `EDUCATION`), whereas others are binary (ex. `SEX`).
#
# According to the correlation map above, `PAY_*` features have the highest correlation to default on payment. Specifically, `PAY_0` has the highest correlation to default on payment of all features.
#
# #### Additional Metrics for Assessment
#
# Additionally, we see that we have class imbalance among the target features, with around 78% of examples with a default on payment and 22% without a default on payment. This means that the default scoring method in cross validation methods from `sklearn` will not be reliable. A more reliable metric would be using accuracy in conjunction with F1 score.

# %% [markdown]
# <!-- END QUESTION -->
#
# <br><br>

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ## 4. Feature engineering <a name="4"></a>
# <hr>
# rubric={points:1}
#
# **Your tasks:**
#
# 1. Carry out feature engineering. In other words, extract new features relevant for the problem and work with your new feature set in the following exercises. You may have to go back and forth between feature engineering and preprocessing.

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_4
#
# </div>
#
# _Points:_ 1

# %%
for df in [X_train, X_test]:
    # Payment status features
    df['avg_pay_stat'] = df[['PAY_0', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6']].mean(axis=1)
    df['payment_delays'] = (df[['PAY_0', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6']] > 0).sum(axis=1)
    
    # Bill-related features
    df['avg_bill'] = df[['BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6']].mean(axis=1)
    df['avg_payment'] = df[['PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6']].mean(axis=1)
    
    # Ratios
    df['utilization'] = df['avg_bill'] / df['LIMIT_BAL']
    df['payment_ratio'] = df['avg_payment'] / df['avg_bill'].replace(0, 1)  # needed since i was getting division by 0

new_numeric_features = ['avg_pay_stat', 'payment_delays', 'avg_bill', 'avg_payment', 'utilization', 'payment_ratio']

display(X_train)
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# ID
# 16396   320000.0    2          1         2   36      0      0      0      0
# 21449   440000.0    2          1         2   30     -1     -1     -1      0
# 20035   160000.0    2          3         1   44     -2     -2     -2     -2
# 25756   120000.0    2          2         1   30      0      0      0      0
# 1439     50000.0    1          2         2   54      1      2      0      0
# ...          ...  ...        ...       ...  ...    ...    ...    ...    ...
# 28637   380000.0    2          2         1   37      0      0      0      0
# 17731   360000.0    2          1         1   54      1     -2     -2     -1
# 28031    50000.0    2          3         1   29      0      0      0      0
# 15726    30000.0    2          2         2   21      0      0      0      0
# 19967   370000.0    2          1         1   36     -2     -2     -2     -2
#
# ...

# %% [markdown]
# <!-- END QUESTION -->
#
# <br><br>

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ## 5. Preprocessing and transformations <a name="5"></a>
# <hr>
# rubric={points:10}
#
# **Your tasks:**
#
# 1. Identify different feature types and the transformations you would apply on each feature type.
# 2. Define a column transformer, if necessary.

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_5
#
# </div>
#
# _Points:_ 10

# %%
numeric_features = new_numeric_features + [
    'LIMIT_BAL', 'AGE',
    'BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6',
    'PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6'
]

categorical_features = ['SEX', 'MARRIAGE']

payment_status_features = ['PAY_0', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6']

education_feature = ['EDUCATION']

preprocessor = make_column_transformer(
    # Standard scaling for numeric features
    (StandardScaler(), numeric_features),

    # One-hot encoding for binary features
    (OneHotEncoder(drop="if_binary"), categorical_features),
    
    # Ordinal encoding for payment status
    (OrdinalEncoder(
        categories=[sorted(np.arange(-2, 9))] * len(payment_status_features),
        handle_unknown='use_encoded_value',
        unknown_value=-999
    ), payment_status_features),
    
    # Ordinal encoding for education - using -999 as unknown value
    (OrdinalEncoder(
        categories=[[0, 1, 2, 3, 4, 5, 6]],
        handle_unknown='use_encoded_value',
        unknown_value=-999
    ), education_feature)
)

preprocessor
# Out:
# ColumnTransformer(transformers=[('standardscaler', StandardScaler(),
#                                  ['avg_pay_stat', 'payment_delays', 'avg_bill',
#                                   'avg_payment', 'utilization', 'payment_ratio',
#                                   'LIMIT_BAL', 'AGE', 'BILL_AMT1', 'BILL_AMT2',
#                                   'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5',
#                                   'BILL_AMT6', 'PAY_AMT1', 'PAY_AMT2',
#                                   'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5',
#                                   'PAY_AMT6']),
#                                 ('onehotencoder',
#                                  OneHotEncoder(drop='...
#                                                              4, 5, 6, 7, 8],
#                                                             [-2, -1, 0, 1, 2, 3,
#                                                              4, 5, 6, 7, 8],
# ...

# %% [markdown]
# <!-- END QUESTION -->
#
# <br><br>

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ## 6. Baseline model <a name="6"></a>
# <hr>
# rubric={points:2}
#
# **Your tasks:**
# 1. Try `scikit-learn`'s baseline model and report results.

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_6
#
# </div>
#
# _Points:_ 2

# %%
results_dict = {}

dummy = DummyClassifier(strategy="most_frequent", random_state=42)
pipe_dc = make_pipeline(preprocessor, dummy)

cv_results = cross_validate(
    pipe_dc,
    X_train,
    y_train,
    cv=5,
    scoring=['accuracy', 'f1'],
    return_train_score=True
)

cv_results_df = pd.DataFrame(cv_results)
cv_results_df
# Out:
#    fit_time  score_time  test_accuracy  train_accuracy  test_f1  train_f1
# 0  0.017505    0.005144       0.776905        0.776726      0.0       0.0
# 1  0.012589    0.004976       0.776905        0.776726      0.0       0.0
# 2  0.012291    0.004878       0.776667        0.776786      0.0       0.0
# 3  0.012168    0.004824       0.776667        0.776786      0.0       0.0
# 4  0.012245    0.005005       0.776667        0.776786      0.0       0.0

# %% [markdown]
# <!-- END QUESTION -->
#
# <br><br>

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ## 7. Linear models <a name="7"></a>
# <hr>
# rubric={points:10}
#
# **Your tasks:**
#
# 1. Try a linear model as a first real attempt.
# 2. Carry out hyperparameter tuning to explore different values for the complexity hyperparameter.
# 3. Report cross-validation scores along with standard deviation.
# 4. Summarize your results.

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_7
#
# </div>
#
# _Points:_ 10

# %% [markdown]
# #### Summary of Results
#
# The logistic regression model achieves consistent accuracy of around 0.810 and an F1 score of around 0.39 across different hyperparameter values. The small standard deviations listed above indicate that the model shows relatively stable performance.
#
# Investigating different hyperparameter values (C), observe that there is very little difference in both the train scores and CV scores. This indicates that the model is not overfitting for any hyperparameter value.
#
# The small difference between the training and CV scores indicates that the model is able to generalize well, neither overfitting nor underfitting.
#
# The consistent CV scores across different C values might indicate that we have reached the model's capacity given the dataset, and further hyperparameter optimizations may not be helpful.

# %%
C_values = [0.001, 0.01, 0.1, 1, 10, 100, 1000]

results_dict = {}

for C in C_values:
    lr_pipe = make_pipeline(
        preprocessor,
        LogisticRegression(C=C, random_state=42, max_iter=2000)
    )
    
    cv_results = cross_validate(
        lr_pipe, 
        X_train,
        y_train,
        cv=5,
        scoring=['accuracy', 'f1'],
        return_train_score=True
    )
    
    results_dict[C] = {
        'train_accuracy': cv_results['train_accuracy'].mean(),
        'train_std': cv_results['train_accuracy'].std(),
        'cv_accuracy': cv_results['test_accuracy'].mean(),
        'cv_std': cv_results['test_accuracy'].std(),
        'fit_time': cv_results['fit_time'].mean(),
        'score_time': cv_results['score_time'].mean(),
        'train_f1': cv_results['train_f1'].mean(),
        'test_f1': cv_results['test_f1'].mean(),
    }
results_df = pd.DataFrame(results_dict).T
results_df
# Out:
#           train_accuracy  train_std  cv_accuracy    cv_std  fit_time  \
# 0.001           0.806583   0.000484     0.806429  0.002146  0.027737
# 0.010           0.809143   0.000749     0.809048  0.002087  0.040625
# 0.100           0.808964   0.000619     0.808429  0.002196  0.070510
# 1.000           0.809214   0.000758     0.808524  0.002017  0.057974
# 10.000          0.809238   0.000697     0.808571  0.001969  0.063154
# 100.000         0.809167   0.000655     0.808571  0.001875  0.060739
# 1000.000        0.809202   0.000733     0.808476  0.001990  0.062107
#
#           score_time  train_f1   test_f1
# 0.001       0.005079  0.365562  0.364597
# 0.010       0.005018  0.402219  0.402097
# 0.100       0.005064  0.406724  0.404866
# 1.000       0.005218  0.408261  0.405515
# 10.000      0.005049  0.408512  0.405932
# 100.000     0.005133  0.408246  0.405775
# 1000.000    0.005090  0.408248  0.405461

# %% [markdown]
# #### Additional Metrics
#
# Below is the classification report of predictions made by the logistic regression model and how they compare to the true prediction.
#
# Observe that the model has great precision score for both classes, with a very high recall and F1 score for classifications under class 0. In contrast, very low recall and F1 score for class 1. Additionally, this further reinforces the effects of class imbalance in our dataset influencing our model training and performance.

# %%
lr_pipe = make_pipeline(
        preprocessor,
        LogisticRegression(C=100, random_state=42, max_iter=2000)
    )

predictions = cross_val_predict(lr_pipe, X_train, y_train)
print(classification_report(y_train, predictions, target_names=["0", "1"], digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.8248    0.9568    0.8859     16312
#            1     0.6607    0.2929    0.4059      4688
#
#     accuracy                         0.8086     21000
#    macro avg     0.7428    0.6248    0.6459     21000
# weighted avg     0.7882    0.8086    0.7787     21000

# %% [markdown]
# <!-- END QUESTION -->
#
# <br><br>

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ## 8. Different models <a name="8"></a>
# <hr>
# rubric={points:12}
#
# **Your tasks:**
# 1. Try at least 3 other models aside from a linear model. One of these models should be a tree-based ensemble model.
# 2. Summarize your results in terms of overfitting/underfitting and fit and score times. Can you beat a linear model?

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_8
#
# </div>
#
# _Points:_ 12

# %% [markdown]
# #### Comparison of Results
#
# **1. Random Forest:**
# - Large gap between train (0.999) and CV (0.815) accuracy indicates overfitting
# - Achieves better F1 score (0.471) despite overfitting
#
# **2. Gradient Boosting:**
# - Small gap between train (0.830) and CV (0.820) accuracy
# - Best F1 score (0.478) among all models
#
# **3. SVM:**
# - Small gap between train (0.822) and CV (0.819) accuracy indicates good fit
# - F1 score of 0.465
#
# #### Table Comparing Fit and Score Times
#
# | **Model** | Fit time (s) | Score time (s) |
# | --- | --- | --- |
# | Random Forest | ~4 | ~0.06 |
# | Gradient Boosting | ~7 | ~0.009 |
# | SVM | ~5.7 | ~1.36 |
#
#
# #### Can we beat the linear model?
#
# Yes, and the improvement seems to be significant due to a drastic increase in F1 score.
#
# While CV accuracy improvements are minimal, F1 scores show significant improvement, across all non-linear models. The non-linear models achieve F1 scores of around 0.47 compared to around 0.40 for logistic regression. This indicates that non-linear models are better able to handle this case of class imbalance. However, this comes with significant computational trade-offs (much slower fitting). Gradient Boosting offers the best balance: highest F1 score, good fit, and moderate computational cost.
#
# Using the F1 score as an assessment metric shows that non-linear models are significantly better at handling the class imbalance in this dataset, which may make them a viable option if correct predictions are not as important as computational costs.

# %%
model_results = {}

# RandomForest
rf_pipe = make_pipeline(
    preprocessor,
    RandomForestClassifier(n_estimators=100, random_state=42)
)

# GradientBoost
gb_pipe = make_pipeline(
    preprocessor,
    GradientBoostingClassifier(n_estimators=100, random_state=42)
)

# SVM
svm_pipe = make_pipeline(
    preprocessor,
    SVC(random_state=42)
)

models = {
    'Random Forest': rf_pipe,
    'Gradient Boosting': gb_pipe,
    'SVM': svm_pipe
}

for name, model in models.items():
    cv_results = cross_validate(
        model,
        X_train,
        y_train,
        cv=5,
        scoring=['accuracy', 'f1'],
        return_train_score=True,
        n_jobs=-1
    )
    
    model_results[name] = {
        'train_accuracy': cv_results['train_accuracy'].mean(),
        'train_std': cv_results['train_accuracy'].std(),
        'cv_accuracy': cv_results['test_accuracy'].mean(),
        'cv_std': cv_results['test_accuracy'].std(),
        'fit_time': cv_results['fit_time'].mean(),
        'score_time': cv_results['score_time'].mean(),
        'train_f1': cv_results['train_f1'].mean(),
        'test_f1': cv_results['test_f1'].mean(),
    }

results_df = pd.DataFrame(model_results).T
results_df
# Out:
#                    train_accuracy  train_std  cv_accuracy    cv_std  fit_time  \
# Random Forest            0.999393   0.000095     0.815857  0.004218  3.969186
# Gradient Boosting        0.830405   0.001682     0.819667  0.003986  7.297175
# SVM                      0.822024   0.001060     0.818810  0.003573  5.319995
#
#                    score_time  train_f1   test_f1
# Random Forest        0.055743  0.998639  0.477954
# Gradient Boosting    0.010094  0.508763  0.478080
# SVM                  1.313244  0.474584  0.464789

# %% [markdown]
# <!-- END QUESTION -->
#
# <br><br>

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ## 9. Feature selection <a name="9"></a>
# <hr>
# rubric={points:2}
#
# **Your tasks:**
#
# Make some attempts to select relevant features. You may try `RFECV` or forward selection for this. Do the results improve with feature selection? Summarize your results. If you see improvements in the results, keep feature selection in your pipeline. If not, you may abandon it in the next exercises.

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_9
#
# </div>
#
# _Points:_ 2

# %% [markdown]
# #### Feature Select with `RFECV`
#
# I attempted feature selection using `RFECV`. The results show that out of our original feature set, 17 features were selected as most important. The selected features are: ['avg_pay_stat', 'payment_delays', 'avg_payment', 'payment_ratio',_'LIMIT_BAL', 'BILL_AMT1', 'BILL_AMT2', 'PAY_AMT1', 'SEX_2', 'MARRIAGE_0', 'MARRIAGE_1', 'MARRIAGE_3', 'PAY_0', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5']
#
# However, when comparing model performance with all features versus only selected features, the model performs better with the complete feature set. Based on these results, I will not be including feature selection in my pipeline since removing features appears to reduce model performance. This shows that even features not selected by `RFECV` contain valuable information for predicting credit card default.

# %%
X_train_scaled = preprocessor.fit_transform(X_train)

feature_names = (
    numeric_features +
    preprocessor.named_transformers_['onehotencoder'].get_feature_names_out(categorical_features).tolist() +
    payment_status_features +
    education_feature
)

rfe_cv = RFECV(
    LogisticRegression(max_iter=2000),
    scoring="f1",
    min_features_to_select=5,
    cv=5,
)

rfe_cv.fit(X_train_scaled, y_train)

selected_features = [name for name, selected in zip(feature_names, rfe_cv.support_) if selected]
selected_features
# Out:
# ['avg_pay_stat',
#  'payment_delays',
#  'avg_payment',
#  'payment_ratio',
#  'LIMIT_BAL',
#  'BILL_AMT1',
#  'BILL_AMT2',
#  'PAY_AMT1',
#  'SEX_2',
#  'MARRIAGE_0',
#  'MARRIAGE_1',
#  'MARRIAGE_3',
#  'PAY_0',
#  'PAY_2',
#  'PAY_3',
#  'PAY_4',
#  'PAY_5']

# %%
rfe_pipe = make_pipeline(
    StandardScaler(),
    rfe_cv,
)

pd.DataFrame(cross_validate(rfe_pipe, X_train, y_train, scoring=['accuracy', 'f1'], return_train_score=True)).mean()
# Out:
# fit_time          1.465442
# score_time        0.002441
# test_accuracy     0.808333
# train_accuracy    0.809131
# test_f1           0.402942
# train_f1          0.406883
# dtype: float64

# %% [markdown]
# <!-- END QUESTION -->
#
# <br><br>

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ## 10. Hyperparameter optimization <a name="10"></a>
# <hr>
# rubric={points:10}
#
# **Your tasks:**
#
# Make some attempts to optimize hyperparameters for the models you've tried and summarize your results. In at least one case you should be optimizing multiple hyperparameters for a single model. You may use `sklearn`'s methods for hyperparameter optimization or fancier Bayesian optimization methods.
#   - [GridSearchCV](http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html)
#   - [RandomizedSearchCV](http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.RandomizedSearchCV.html)
#   - [scikit-optimize](https://github.com/scikit-optimize/scikit-optimize)

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_10
#
# </div>
#
# _Points:_ 10

# %% [markdown]
# #### Hyperparameter Optimization for Logistic Regression
#
# For the Logistic Regression model, I performed grid search optimization over two parameters:
#
# - C: [0.001, 0.01, 0.1, 1.0, 10.0, 100.0, 1000.0]
# - class_weight: ["balanced", None]
#
# The best parameters were found to be `C=0.01` and `class_weight='balanced'`. This parameter yielded us with an F1 score of 0.53, and an accuracy of around 0.77.
#
# The model performance is relatively stable across C values from 0.01 to 1000, indicated by the small standard deviations across different cross-validation folds.
#
# The minimal differences in performance across different C values might suggest that hyperparameter tuning along may not be enough for significant improvements (we have almost reached the maximum performance capacity allowed by the model).

# %%
lr_pipe = make_pipeline(
        preprocessor,
        LogisticRegression(max_iter=2000)
)

param_grid = {
    'logisticregression__C': [0.001, 0.01, 0.1, 1, 10, 100, 1000],
    'logisticregression__class_weight': ['balanced', None]
}

gs = GridSearchCV(
    lr_pipe, param_grid, n_jobs = -1, cv = 5, scoring=['accuracy', "f1"], refit='f1', return_train_score = True
)

gs.fit(X_train, y_train)

pd.DataFrame(gs.cv_results_).set_index('rank_test_f1').sort_index().T
# Out:
# rank_test_f1                                                                           1   \
# mean_fit_time                                                                    0.087995
# std_fit_time                                                                     0.010936
# mean_score_time                                                                   0.01276
# std_score_time                                                                    0.00289
# param_logisticregression__C                                                          0.01
# param_logisticregression__class_weight                                           balanced
# params                                  {'logisticregression__C': 0.01, 'logisticregre...
# split0_test_accuracy                                                             0.760714
# split1_test_accuracy                                                             0.772619
# ...

# %%
display(pd.DataFrame(gs.cv_results_)[[
    'mean_test_f1',
    'mean_test_accuracy',
    'param_logisticregression__C',
    'param_logisticregression__class_weight',
    'mean_fit_time',
    'rank_test_f1',
    'std_test_accuracy',
    'std_test_f1',
]].set_index('rank_test_f1').sort_index().T)
# Out:
# rank_test_f1                                  1         2         3   \
# mean_test_f1                             0.53396  0.533245  0.532739
# mean_test_accuracy                      0.770286  0.770524  0.769238
# param_logisticregression__C                 0.01     0.001       0.1
# param_logisticregression__class_weight  balanced  balanced  balanced
# mean_fit_time                           0.087995  0.051792  0.106217
# std_test_accuracy                       0.005127  0.005862  0.005094
# std_test_f1                             0.006517   0.00738  0.005922
#
# rank_test_f1                                  4         5         6   \
# mean_test_f1                            0.532436  0.532398  0.532295
# mean_test_accuracy                      0.769048  0.769095     0.769
# param_logisticregression__C               1000.0      10.0       1.0
# param_logisticregression__class_weight  balanced  balanced  balanced
# ...

# %%
best_params = gs.best_params_
best_params
# Out:
# {'logisticregression__C': 0.01, 'logisticregression__class_weight': 'balanced'}

# %%
best_lr_pipe = make_pipeline(preprocessor, LogisticRegression(C=0.01, class_weight='balanced', max_iter=2000))
best_lr_pipe.fit(X_train, y_train)
best_lr_pipe.score(X_train, y_train)
# Out:
# 0.7713809523809524

# %% [markdown]
# #### Hyperparameter Optimization for Random Forests
#
# For the Random Forest model, I performed randomized search optimization over three hyperparameters:
# - n_estimators (number of trees): range from 50 to 200
# - max_depth (maximum tree depth): [5, 10, 30]
# - class_weight: ['balanced', None]
#
# The best parameters were found to be `n_estimators=137`, `max_depth=10`, and `class_weight='balanced'`. This combination yielded an F1 score of 0.545 and an accuracy of 0.792. This represents a significant improvement over the logistic regression model (F1 score of 0.40).
#
# The model shows stable performance across different parameter combinations, as indicated by small standard deviations in both F1 score (0.014) and accuracy (0.009).

# %%
rf_pipe = make_pipeline(
    preprocessor,
    RandomForestClassifier(random_state=42)
)

rf_param_dist = {
    'randomforestclassifier__n_estimators': randint(50, 200),
    'randomforestclassifier__max_depth': [5, 10, 30],
    'randomforestclassifier__class_weight': ['balanced', None]
}

rf_random = RandomizedSearchCV(
    rf_pipe,
    rf_param_dist,
    n_iter=10,
    cv=5,
    n_jobs=-1,
    scoring=["accuracy", "f1"],
    refit="f1",
    random_state=42,
    return_train_score=True
)

rf_random.fit(X_train, y_train)

pd.DataFrame(rf_random.cv_results_).set_index('rank_test_f1').sort_index().T
# Out:
# rank_test_f1                                                                               1   \
# mean_fit_time                                                                         4.24636
# std_fit_time                                                                          0.14151
# mean_score_time                                                                      0.050652
# std_score_time                                                                        0.00225
# param_randomforestclassifier__class_weight                                           balanced
# param_randomforestclassifier__max_depth                                                    10
# param_randomforestclassifier__n_estimators                                                137
# params                                      {'randomforestclassifier__class_weight': 'bala...
# split0_test_accuracy                                                                 0.779524
# ...

# %%
display(pd.DataFrame(rf_random.cv_results_)[[
    'mean_test_f1',
    'mean_test_accuracy',
    'param_randomforestclassifier__max_depth',
    'param_randomforestclassifier__n_estimators',
    'mean_fit_time',
    'rank_test_f1',
    'std_test_accuracy',
    'std_test_f1',
]].set_index('rank_test_f1').sort_index().T)
# Out:
# rank_test_f1                                        1           2          3   \
# mean_test_f1                                  0.545032    0.544869   0.542266
# mean_test_accuracy                            0.792000    0.792333   0.764381
# param_randomforestclassifier__max_depth      10.000000   10.000000   5.000000
# param_randomforestclassifier__n_estimators  137.000000  124.000000  64.000000
# mean_fit_time                                 4.246360    3.665899   1.306433
# std_test_accuracy                             0.008207    0.008647   0.008861
# std_test_f1                                   0.013675    0.014756   0.013099
#
# rank_test_f1                                       4           5           6   \
# mean_test_f1                                 0.541742    0.540379    0.483296
# mean_test_accuracy                           0.764143    0.761619    0.816952
# param_randomforestclassifier__max_depth      5.000000    5.000000   30.000000
# ...

# %%
best_params = rf_random.best_params_
best_params
# Out:
# {'randomforestclassifier__class_weight': 'balanced',
#  'randomforestclassifier__max_depth': 10,
#  'randomforestclassifier__n_estimators': 137}

# %%
rf_random.best_score_
# Out:
# 0.5450322106482187

# %% [markdown]
# #### Hyperparameter Optimization for Gradient Boosting
#
# For the Gradient Boosting model, I performed randomized search optimization over three hyperparameters:
# - n_estimators (number of trees): range from 50 to 200
# - max_depth (maximum tree depth): [3, 5, 7]
#
# The best parameters were found to be `n_estimators=70`, `max_depth=3`. This combination yielded an F1 score of 0.475 and an accuracy of 0.82. This represents a significant improvement over the logistic regression model (F1 score of 0.40).
#
# The model shows stable performance across different parameter combinations, as indicated by small standard deviations in both F1 score (0.0129) and accuracy (0.004).

# %%
gb_pipe = make_pipeline(
    preprocessor,
    GradientBoostingClassifier(random_state=42)
)

gb_param_dist = {
    'gradientboostingclassifier__n_estimators': randint(50, 200),
    'gradientboostingclassifier__max_depth': [3, 5, 7],
}

gb_random = RandomizedSearchCV(
    gb_pipe,
    gb_param_dist,
    n_iter=5,
    cv=5,
    n_jobs=-1,
    scoring=["accuracy", "f1"],
    refit="f1",
    random_state=42,
    return_train_score=True,
)

gb_random.fit(X_train, y_train)

pd.DataFrame(gb_random.cv_results_).set_index('rank_test_f1').sort_index().T
# Out:
# rank_test_f1                                                                                    1  \
# mean_fit_time                                                                            6.378166
# std_fit_time                                                                             0.070318
# mean_score_time                                                                           0.01352
# std_score_time                                                                           0.002129
# param_gradientboostingclassifier__max_depth                                                     3
# param_gradientboostingclassifier__n_estimators                                                 70
# params                                          {'gradientboostingclassifier__max_depth': 3, '...
# split0_test_accuracy                                                                        0.815
# ...

# %%
display(pd.DataFrame(gb_random.cv_results_)[[
    'mean_test_f1',
    'mean_test_accuracy',
    'param_gradientboostingclassifier__max_depth',
    'param_gradientboostingclassifier__n_estimators',
    'mean_fit_time',
    'rank_test_f1',
   'std_test_accuracy',
    'std_test_f1',
]].set_index('rank_test_f1').sort_index().T)
# Out:
# rank_test_f1                                            1           2  \
# mean_test_f1                                     0.474880    0.472542
# mean_test_accuracy                               0.819429    0.813667
# param_gradientboostingclassifier__max_depth      3.000000    7.000000
# param_gradientboostingclassifier__n_estimators  70.000000  142.000000
# mean_fit_time                                    6.378166   28.393333
# std_test_accuracy                                0.003769    0.003957
# std_test_f1                                      0.012894    0.011663
#
# rank_test_f1                                             3           4  \
# mean_test_f1                                      0.470846    0.470784
# mean_test_accuracy                                0.813762    0.813190
# param_gradientboostingclassifier__max_depth       7.000000    7.000000
# param_gradientboostingclassifier__n_estimators  124.000000  156.000000
# ...

# %%
best_params = gb_random.best_params_
best_params
# Out:
# {'gradientboostingclassifier__max_depth': 3,
#  'gradientboostingclassifier__n_estimators': 70}

# %%
best_score = gb_random.best_score_
best_score
# Out:
# 0.4748795129560883

# %% [markdown]
# #### Hyperparameter Optimization for SVM
#
# For the Gradient Boosting model, I performed randomized search optimization over three hyperparameters:
# - gamma: evenly spaced numbers over interval [0.001, 0.1]
# - C: evenly spaced numbers over interval [0.1, 10]
#
# The best parameters were found to be `gamma=0.051`, and `C=10`. This combination yielded an F1 score of 0.46 and an accuracy of 0.81. This represents a significant improvement over the logistic regression model (F1 score of 0.40).

# %%
svc_pipe = make_pipeline(
    preprocessor,
    SVC(random_state=42, kernel='rbf')
)

svc_param_dist = {
    'svc__gamma': np.linspace(0.001, 0.1, 3),
    'svc__C': np.linspace(0.1, 10, 3)
}

svc_random = RandomizedSearchCV(
    svc_pipe,
    svc_param_dist,
    n_iter=5,
    cv=5,
    n_jobs=-1,
    scoring=["accuracy", "f1"],
    refit="f1",
    random_state=42,
    return_train_score=True
)

svc_random.fit(X_train, y_train)

pd.DataFrame(svc_random.cv_results_).set_index('rank_test_f1').sort_index().T
# Out:
# rank_test_f1                                                1  \
# mean_fit_time                                       16.082123
# std_fit_time                                         0.804372
# mean_score_time                                      2.042598
# std_score_time                                       0.050725
# param_svc__gamma                                       0.0505
# param_svc__C                                             10.0
# params                 {'svc__gamma': 0.0505, 'svc__C': 10.0}
# split0_test_accuracy                                 0.810476
# split1_test_accuracy                                 0.812619
# split2_test_accuracy                                 0.815238
# split3_test_accuracy                                 0.820476
# split4_test_accuracy                                 0.811667
# mean_test_accuracy                                   0.814095
# std_test_accuracy                                    0.003555
# ...

# %%
display(pd.DataFrame(svc_random.cv_results_)[[
    'mean_test_f1',
    'mean_test_accuracy',
    'param_svc__gamma',
    'param_svc__C',
    'mean_fit_time',
    'rank_test_f1',
    'std_test_accuracy',
    'std_test_f1',
]].set_index('rank_test_f1').sort_index().T)
# Out:
# rank_test_f1                1          2         3          4         5
# mean_test_f1         0.460280   0.456527  0.451653   0.446134  0.264275
# mean_test_accuracy   0.814095   0.813048  0.816714   0.807143  0.798238
# param_svc__gamma     0.050500   0.100000  0.050500   0.100000  0.001000
# param_svc__C        10.000000   5.050000  0.100000  10.000000  0.100000
# mean_fit_time       16.082123  19.472636  7.600842  18.731298  6.104982
# std_test_accuracy    0.003555   0.002815  0.002979   0.003275  0.002431
# std_test_f1          0.012101   0.007573  0.006029   0.006720  0.017758

# %%
best_params = svc_random.best_params_
best_params
# Out:
# {'svc__gamma': 0.0505, 'svc__C': 10.0}

# %%
best_score = svc_random.best_score_
best_score
# Out:
# 0.4602798491146672

# %% [markdown]
# <!-- END QUESTION -->
#
# <br><br>

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ## 11. Interpretation and feature importances <a name="1"></a>
# <hr>
# rubric={points:10}
#
# **Your tasks:**
#
# 1. Use the methods we saw in class (e.g., `shap`) (or any other methods of your choice) to examine the most important features of one of the non-linear models.
# 2. Summarize your observations.

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_11
#
# </div>
#
# _Points:_ 10

# %% [markdown]
# #### Summary of Feature Importances for Random Forests
#
# After investigating the Random Forest model, the top important features are related to payment status, specifically the `PAY_*` features:
#
# - `payment_delays` (feature engineered) stands out as the most important (0.142)
# - `PAY_0` (most recent payment status) follows closely with 0.116 importance
# - `avg_pay_stat` (feature engineered) shows high importance (0.08)
#
# Other payment statuses (`PAY_2`, `PAY_3`, `PAY_4`, etc.) show decreasing importance, ranging from 0.074 to 0.02.
#
# Additionally, it appears that other financially related features also contribute (`avg_payment`, `utilization`, and `avg_bill` show importance of around 0.03-0.04).
#
# Individual payment amounts (`PAY_AMT1`-`PAY_AMT6`) and bill amounts (`BILL_AMT1`-`BILL_AMT6`) have lower importance of around 0.02-0.03.
#
# Demographic features consistently demonstrate low importance (`AGE`, `EDUCATION`, `SEX`, and `MARRIAGE`). All have importance scores below 0.02, with some being significantly lower (e.g., marriage status features below 0.003).
#
# In summary, the model prioritizes recent payment behavior and overall payment statistics, as captured by the `PAY_*` features and engineered features like `payment_delays` and `avg_pay_stat`. Demographic information plays a minimal role in predictions. This can be reinforced by how our financial institutions in real-life work (demographic features do not matter as much as payment behaviour).

# %%
best_rf_pipe = make_pipeline(preprocessor, RandomForestClassifier(n_estimators=137, max_depth=10, class_weight="balanced"))
best_rf_pipe.fit(X_train, y_train)

preprocessed_features = (
    preprocessor.get_feature_names_out()
)

rf_importances = best_rf_pipe.named_steps['randomforestclassifier'].feature_importances_

importance_df = pd.DataFrame({
    'feature': preprocessed_features,
    'importance': rf_importances
})

importance_df = importance_df.sort_values('importance', ascending=False)

importance_df
# Out:
#                            feature  importance
# 25         ordinalencoder-1__PAY_0    0.131855
# 1   standardscaler__payment_delays    0.123526
# 0     standardscaler__avg_pay_stat    0.094721
# 26         ordinalencoder-1__PAY_2    0.059248
# 4      standardscaler__utilization    0.039893
# 3      standardscaler__avg_payment    0.037894
# 27         ordinalencoder-1__PAY_3    0.036594
# 5    standardscaler__payment_ratio    0.031860
# 2         standardscaler__avg_bill    0.031127
# 6        standardscaler__LIMIT_BAL    0.030828
# 15        standardscaler__PAY_AMT2    0.028946
# 8        standardscaler__BILL_AMT1    0.028224
# 29         ordinalencoder-1__PAY_5    0.027765
# 16        standardscaler__PAY_AMT3    0.027464
# 14        standardscaler__PAY_AMT1    0.025768
# 9        standardscaler__BILL_AMT2    0.025424
# 28         ordinalencoder-1__PAY_4    0.025228
# 11       standardscaler__BILL_AMT4    0.022582
# 17        standardscaler__PAY_AMT4    0.022284
# ...

# %% [markdown]
# <!-- END QUESTION -->
#
# <br><br>

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ## 12. Results on the test set <a name="12"></a>
# <hr>
#
# rubric={points:10}
#
# **Your tasks:**
#
# 1. Try your best performing model on the test data and report test scores.
# 2. Do the test scores agree with the validation scores from before? To what extent do you trust your results? Do you think you've had issues with optimization bias?
# 3. Take one or two test predictions and explain these individual predictions (e.g., with SHAP force plots).

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_12
#
# </div>
#
# _Points:_ 10

# %% [markdown]
# #### Results on Test Set
#
# The best parameters for Random Forest were found to be `n_estimators=137`, `max_depth=10`, and `class_weight='balanced'`.
#
# **1. Test Set Performance**
# Best performing Random Forest model achieved:
#
# | Class | Precision | Recall | F1-Score | Support |
# |-------|-----------|--------|----------|---------|
# | 0     | 0.88      | 0.85   | 0.86     | 7052    |
# | 1     | 0.50      | 0.56   | 0.53     | 1948    |
#
# **2. Validation vs Test Scores and Optimization Bias**
#
# The test accuracy (0.7851) and F1 score (0.5310) are fairly consistent with the validation scores from previous experiments. However, the lower performance on class 1 suggests potential optimization bias. I believe this bias is due to the class imbalance in the dataset. Given these results, I trust the model's performance for class 0, but I would consider adding more examples of class 0 and adjust the model for better generalization on class `1`.
#
# **3. Individual Prediction Analysis**
#
# Using SHAP force plots, I analyzed two test predictions to understand feature contributions of a prediction outcome. For example:
#
# 1. Prediction 1 (correctly predicted true example):
#
# The model predicted a probability of 0.911. The most contributing features pushing the prediction towards the positive class (1) were:
#     - `avg_pay_stat`: Contributed +0.1 to the prediction
#     - `payment_delays`: Contributed +0.09
#     - Recent payment statuses (`PAY_0`, `PAY_2`, etc.): These features also contributed positively, suggesting that recent positive payment behavior increases the likelihood of a positive prediction
#
# `PAY_AMT1` and the 23 other features had small negative contributions, slightly pulling the prediction towards class 0. This observation suggests that for this specific example, recent payment behavior and average payment statistics are the dominant factors driving the prediction.
#
# 2. Prediction 2 (correctly predicted negative example):
#
# The model predicted a probability of 0.687 for this instance. Key features influencing this prediction include:
#
#     - `payment_delays`: A strong negative contribution of -0.535, pushing the prediction significantly towards class 0 (aligns with the intuitive understanding that payment delays should indicate a higher risk (class 0)
#     - `PAY_0`: A positive contribution of +0.03, which suggests that despite the payment delays, a recent positive payment behavior slightly mitigates the risk
#
# 23 other features had a collectively positive contribution of +0.06, indicating a combination of smaller factors also influencing the prediction towards class 0.
#
# Features like `avg_pay_stat`, `LIMIT_BAL`, and `PAY_AMT3` had smaller negative or positive influences. For this specific example, it appears that payment_delays were the most significant driver towards a negative prediction, although other factors like recent payment behavior and a combination of smaller features balanced the outcome.

# %%
# Make predictions on test set using Random Forest pipeline
y_pred = best_rf_pipe.predict(X_test)
y_pred_proba = best_rf_pipe.predict_proba(X_test)

test_accuracy = accuracy_score(y_test, y_pred)
test_f1 = f1_score(y_test, y_pred)

print

print("Test Set Performance:")
print(f"Accuracy: {test_accuracy:.4f}")
print(f"F1 Score: {test_f1:.4f}\n")
print(classification_report(y_test, y_pred))
# Out:
# Test Set Performance:
# Accuracy: 0.7857
# F1 Score: 0.5321
#
#               precision    recall  f1-score   support
#
#            0       0.88      0.85      0.86      7052
#            1       0.50      0.56      0.53      1948
#
#     accuracy                           0.79      9000
#    macro avg       0.69      0.71      0.70      9000
# weighted avg       0.80      0.79      0.79      9000

# %%
plt.figure(figsize=(8, 6))
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix on Test Set')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.show()

# %%
X_test_enc = pd.DataFrame(
    data=preprocessor.transform(X_test),
    columns=feature_names,
    index=X_test.index,
)
X_test_enc.shape
# Out:
# (9000, 32)

# %%
explainer = shap.TreeExplainer(best_rf_pipe.named_steps["randomforestclassifier"])

X_test_transformed = preprocessor.transform(X_test)
test_shap_values = explainer(X_test_enc)

# %%
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...

# %%
y_test_num = y_test.reset_index(drop=True)

# Find indices of correct predictions
pred = best_rf_pipe.predict(X_test)
correct_default_idx = np.where((pred == 1) & (y_test_num == 1))[0][0]
correct_non_default_idx = np.where((pred == 0) & (y_test_num == 0))[0][0]
print(correct_default_idx)
print(correct_non_default_idx)
# Out:
# 2
# 0

# %%
shap.plots.waterfall(test_shap_values[correct_default_idx, :, 1])

# %%
shap.plots.waterfall(test_shap_values[correct_non_default_idx, :, 0])

# %% [markdown]
# <!-- END QUESTION -->
#
# <br><br>

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ## 13. Summary of results <a name="13"></a>
# <hr>
# rubric={points:12}
#
# Imagine that you want to present the summary of these results to your boss and co-workers.
#
# **Your tasks:**
#
# 1. Create a table summarizing important results.
# 2. Write concluding remarks.
# 3. Discuss other ideas that you did not try but could potentially improve the performance/interpretability .
# 3. Report your final test score along with the metric you used at the top of this notebook in the [Submission instructions section](#si).

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_13
#
# </div>
#
# _Points:_ 12

# %% [markdown]
# _Type your answer here, replacing this text._

# %%
results = {
    'best model': ['Random Forest Classifier'],
    'hyperparameters': ['n_estimators=137, max_depth=10, class_weight="balanced'],
    'most influential feature': ['payment_delays'],
    'test accuracy': [0.7851],
    'test F1 Score': [0.5310],
    'validation accuracy': [0.792],
    'validation F1 Score': [0.545], 
}
pd.DataFrame(results).T
# Out:
#                                                                           0
# best model                                         Random Forest Classifier
# hyperparameters           n_estimators=137, max_depth=10, class_weight="...
# most influential feature                                     payment_delays
# test accuracy                                                        0.7851
# test F1 Score                                                         0.531
# validation accuracy                                                   0.792
# validation F1 Score                                                   0.545

# %% [markdown]
# <!-- END QUESTION -->
#
# <br><br>

# %% [markdown]
# <br><br>

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ## 14. Your takeaway <a name="15"></a>
# <hr>
# rubric={points:2}
#
# **Your tasks:**
#
# What is your biggest takeaway from the supervised machine learning material we have learned so far? Please write thoughtful answers.

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_14
#
# </div>
#
# _Points:_ 2

# %% [markdown]
# My biggest takeaway from the supervised machine learning material we have learned so far is that it's hard.
#
# It's hard because it prioritizes understanding of data, and the problem context aside from applying the algorithms. This includes careful data preprocessing and thoughtful feature engineering, which as demonstrated in this exercise, can significantly improve model performance by creating highly relevant features. Additionally, practical considerations, like the computational costs of `GridSearchCV` on larger datasets, required better and smarter design choices, such as using more efficient methods like `RandomizedSearchCV`. Appropriate model selection, using relevant evaluation metrics and cross-validation, and considering potential biases were also crucial. This exercise also taught me that the accuracy isn't the only metric to track and other metrics should also be used (like F1). In conclusion, it seems that success in machine learning comes from understanding data insights to solve real-world problems.

# %% [markdown]
# <!-- END QUESTION -->
#
# <br><br>

# %% [markdown]
# **PLEASE READ BEFORE YOU SUBMIT:**
#
# When you are ready to submit your assignment do the following:
#
# 1. Run all cells in your notebook to make sure there are no errors by doing `Kernel -> Restart Kernel and Clear All Outputs` and then `Run -> Run All Cells`.
# 2. Notebooks with cell execution numbers out of order or not starting from "1" will have marks deducted. Notebooks without the output displayed may not be graded at all (because we need to see the output in order to grade your work).
# 4. Upload the assignment using Gradescope's drag and drop tool. Check out this [Gradescope Student Guide](https://lthub.ubc.ca/guides/gradescope-student-guide/) if you need help with Gradescope submission.
# 5. Make sure that the plots and output are rendered properly in your submitted file. If the .ipynb file is too big and doesn't render on Gradescope, also upload a pdf or html in addition to the .ipynb so that the TAs can view your submission on Gradescope.

# %% [markdown]
# This was a tricky one but you did it!

# %% [markdown]
# ![](img/eva-well-done.png)
